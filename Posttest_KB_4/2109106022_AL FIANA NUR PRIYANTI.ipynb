# %% [markdown]
# ### Nama      : Al Fiana Nur Priyanti <br> NIM         : 2109106022
#
#
# # Posttest KB 4: Data Preprocessing
# ### Import library pandas, numpy dan sklearn

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# ###### Membaca file CSV

# %%
dataset_split = pd.read_csv("Breast_Cancer.csv")

# %% [markdown]
# ###### Menampilkan informasi dataset

# %%
dataset_split.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     4024 non-null   int64
#  1   Race                    4024 non-null   object
#  2   Marital Status          4024 non-null   object
#  3   T Stage                 4024 non-null   object
#  4   N Stage                 4024 non-null   object
#  5   6th Stage               4024 non-null   object
#  6   differentiate           4024 non-null   object
#  7   Grade                   4024 non-null   object
#  8   A Stage                 4024 non-null   object
#  9   Tumor Size              4024 non-null   int64
#  10  Estrogen Status         4024 non-null   object
#  11  Progesterone Status     4024 non-null   object
#  12  Regional Node Examined  4024 non-null   int64
#  13  Reginol Node Positive   4024 non-null   int64
# ...

# %%
dataset_split.head(10)
# Out:
#    Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0   68  White        Married       T1      N1       IIA
# 1   50  White        Married       T2      N2      IIIA
# 2   58  White       Divorced       T3      N3      IIIC
# 3   58  White        Married       T1      N1       IIA
# 4   47  White        Married       T2      N1       IIB
# 5   51  White        Single        T1      N1       IIA
# 6   51  White        Married       T1      N1       IIA
# 7   40  White        Married       T2      N1       IIB
# 8   40  White       Divorced       T4      N3      IIIC
# 9   69  White        Married       T4      N3      IIIC
#
#                differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0      Poorly differentiated     3  Regional           4        Positive
# 1  Moderately differentiated     2  Regional          35        Positive
# 2  Moderately differentiated     2  Regional          63        Positive
# ...

# %% [markdown]
# ## SPLIT DATASET
# ### 1. Membagi Dataset Menjadi Training Set dan Testing Set dengan Proporsi 70:30
#
# test_size = 0.3 untuk mendefinisikan ukuran testing set <br>
# karena pada ketentuan diminta 70% untuk training set dan 30% untuk testing set

# %%
X = dataset_split.iloc[:, :-1]
y = dataset_split.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
print("Dimensi X_Train: ", X_train.shape)
print("Dimensi X_Test: ", X_test.shape)
print("Dimensi y_Train: ", y_train.shape)
print("Dimensi y_Test: ", y_test.shape)
# Out:
# Dimensi X_Train:  (2816, 15)
# Dimensi X_Test:  (1208, 15)
# Dimensi y_Train:  (2816,)
# Dimensi y_Test:  (1208,)

# %% [markdown]
# ## DATA CLEANING
#
# ###### Membaca File Dataset yang Rusak (berisi nilai NULL atau nilai duplikat)

# %%
dataset_split = pd.read_csv("Breast_Cancer_Rusak.csv")
dataset_split.head(10)
# Out:
#    Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0   68  White        Married       T1      N1       IIA
# 1   50  White        Married       T2      N2      IIIA
# 2   58  White       Divorced       T3      N3      IIIC
# 3   58  White            NaN       T1      N1       IIA
# 4   47  White            NaN       T2      N1       IIB
# 5   51  White        Single        T1      N1       IIA
# 6   51  White        Married       T1      N1       IIA
# 7   40  White            NaN       T2      N1       IIB
# 8   40  White            NaN       T4      N3      IIIC
# 9   69  White            NaN       T4      N3      IIIC
#
#                differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0      Poorly differentiated     3  Regional         4.0        Positive
# 1  Moderately differentiated     2  Regional        35.0        Positive
# 2  Moderately differentiated     2  Regional         NaN        Positive
# ...

# %% [markdown]
# ### 2. Menangani Nilai NULL
# .isna().sum() untuk melihat apakah dataset memiliki nilai NULL

# %%
dataset_split.isna().sum()
# Out:
# Age                         0
# Race                        0
# Marital Status             56
# T Stage                     0
# N Stage                     0
# 6th Stage                   0
# differentiate               0
# Grade                       0
# A Stage                     0
# Tumor Size                153
# Estrogen Status             0
# Progesterone Status         0
# Regional Node Examined      0
# Reginol Node Positive       0
# Survival Months           147
# Status                      0
# dtype: int64

# %% [markdown]
# ###### Untuk menangani nilai NULL pada dataset kita dapat menggunakan kelas SimpleImputer pada Scikit-Learn

# %%
from sklearn.impute import SimpleImputer

# %% [markdown]
# ###### Mengubah nilai NULL yang ada dengan Strategy most_frequent (Modus)

# %%
imputer1 = SimpleImputer(strategy="most_frequent")
dataset_split["Marital Status"] = imputer1.fit_transform(dataset_split[["Marital Status"]])
dataset_split.isna().sum()
# Out:
# Age                         0
# Race                        0
# Marital Status              0
# T Stage                     0
# N Stage                     0
# 6th Stage                   0
# differentiate               0
# Grade                       0
# A Stage                     0
# Tumor Size                153
# Estrogen Status             0
# Progesterone Status         0
# Regional Node Examined      0
# Reginol Node Positive       0
# Survival Months           147
# Status                      0
# dtype: int64

# %% [markdown]
# ###### Mengubah nilai NULL yang ada dengan Strategy mean

# %%
imputer2 = SimpleImputer(strategy="mean")
dataset_split["Tumor Size"] = imputer2.fit_transform(dataset_split[["Tumor Size"]])
dataset_split.isna().sum()
# Out:
# Age                         0
# Race                        0
# Marital Status              0
# T Stage                     0
# N Stage                     0
# 6th Stage                   0
# differentiate               0
# Grade                       0
# A Stage                     0
# Tumor Size                  0
# Estrogen Status             0
# Progesterone Status         0
# Regional Node Examined      0
# Reginol Node Positive       0
# Survival Months           147
# Status                      0
# dtype: int64

# %% [markdown]
# ###### Mengubah nilai NULL yang ada dengan Strategy median

# %%
imputer3 = SimpleImputer(strategy="median")
dataset_split["Survival Months"] = imputer3.fit_transform(dataset_split[["Survival Months"]])
dataset_split.isna().sum()
# Out:
# Age                       0
# Race                      0
# Marital Status            0
# T Stage                   0
# N Stage                   0
# 6th Stage                 0
# differentiate             0
# Grade                     0
# A Stage                   0
# Tumor Size                0
# Estrogen Status           0
# Progesterone Status       0
# Regional Node Examined    0
# Reginol Node Positive     0
# Survival Months           0
# Status                    0
# dtype: int64

# %% [markdown]
# ###### Nilai NULL Berhasil Ditangani

# %%
dataset_split.head(10)
# Out:
#    Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0   68  White        Married       T1      N1       IIA
# 1   50  White        Married       T2      N2      IIIA
# 2   58  White       Divorced       T3      N3      IIIC
# 3   58  White        Married       T1      N1       IIA
# 4   47  White        Married       T2      N1       IIB
# 5   51  White        Single        T1      N1       IIA
# 6   51  White        Married       T1      N1       IIA
# 7   40  White        Married       T2      N1       IIB
# 8   40  White        Married       T4      N3      IIIC
# 9   69  White        Married       T4      N3      IIIC
#
#                differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0      Poorly differentiated     3  Regional    4.000000        Positive
# 1  Moderately differentiated     2  Regional   35.000000        Positive
# 2  Moderately differentiated     2  Regional   30.584862        Positive
# ...

# %% [markdown]
# ### 3. Menangani Nilai Duplikat
# ###### Mengecek Data dan Jumlah Nilai Duplikat

# %%
dataset_split[dataset_split.duplicated()]
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 894    47  White        Married       T3      N2      IIIA
# 895    65  White        Married       T2      N1       IIB
# 896    67  White        Married       T3      N2      IIIA
# 921    47  White        Married       T3      N2      IIIA
# 922    65  White        Married       T2      N1       IIB
# 923    67  White        Married       T3      N2      IIIA
# 2831   63  White        Single        T2      N1       IIB
# 2832   60  White        Married       T3      N2      IIIA
# 2833   49  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 894         Well differentiated     1  Regional       133.0        Positive
# 895         Well differentiated     1  Regional        22.0        Positive
# 896       Poorly differentiated     3  Regional        55.0        Positive
# ...

# %%
dataset_split.duplicated().sum()
# Out:
# 9

# %% [markdown]
# ###### Menangani Nilai Duplikat dengan fungsi drop_duplicates(inplace=True)

# %%
dataset_split.drop_duplicates(inplace=True)

# %% [markdown]
# ###### Nilai Duplikat Berhasil Ditangani

# %%
dataset_split[dataset_split.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Age, Race, Marital Status, T Stage , N Stage, 6th Stage, differentiate, Grade, A Stage, Tumor Size, Estrogen Status, Progesterone Status, Regional Node Examined, Reginol Node Positive, Survival Months, Status]
# Index: []

# %%
dataset_split.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## DATA TRANSFORMING
#
# Terdapat 5 atribut yang saya gunakan dalam Data Transforming yaitu Age, Tumor Size, Regional Node Examined, Reginol Node Positive, dan Survival Months.
#
# ### 4. Normalization

# %% [markdown]
# ###### Untuk Transformasi Data Normalisasi perlu menggunakan kelas MinMaxScaler pada Scikit-Learn

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min_max_scaler = MinMaxScaler()

# %%
x_scaled = min_max_scaler.fit_transform(
    dataset_split[['Age','Tumor Size','Regional Node Examined',
                   'Reginol Node Positive','Survival Months']]
)

# %% [markdown]
# ###### Proses normalisasi telah berhasil

# %%
data_normalization = pd.DataFrame(x_scaled)
data_normalization.head()
# Out:
#           0         1         2         3         4
# 0  0.974359  0.021583  0.383333  0.000000  0.552381
# 1  0.512821  0.244604  0.216667  0.088889  0.571429
# 2  0.717949  0.212841  0.216667  0.133333  0.695238
# 3  0.717949  0.212841  0.016667  0.000000  0.780952
# 4  0.435897  0.287770  0.033333  0.000000  0.676190

# %% [markdown]
# ### 5. Standarization
#
# np.std() untuk melihat nilai standar deviasi dari dataset.

# %%
np.std(dataset_split)
# Out:
# Age                        8.963527
# Tumor Size                20.607831
# Regional Node Examined     8.096189
# Reginol Node Positive      5.099610
# Survival Months           22.464203
# dtype: float64

# %% [markdown]
# ###### Untuk Transformasi Data Standarisasi perlu menggunakan kelas StandardScaler pada Scikit-Learn

# %%
from sklearn.preprocessing import StandardScaler

# %%
standard_scaler = StandardScaler()

# %%
x_scaled2 = standard_scaler.fit_transform(
    dataset_split[['Age','Tumor Size','Regional Node Examined',
                   'Reginol Node Positive','Survival Months']]
)

# %% [markdown]
# ###### Proses standarisasi telah berhasil

# %%
data_standarization = pd.DataFrame(x_scaled2)
data_standarization.head()
# Out:
#           0         1         2         3         4
# 0  1.565220 -1.286874  1.190542 -0.618415 -0.504214
# 1 -0.442919  0.217409 -0.044607  0.165959 -0.415184
# 2  0.449587  0.003163 -0.044607  0.558146  0.163515
# 3  0.449587  0.003163 -1.526786 -0.618415  0.564152
# 4 -0.777608  0.508560 -1.403271 -0.618415  0.074484

# %%
np.std(x_scaled2)
# Out:
# 1.0

# %%
np.mean(x_scaled2)
# Out:
# -1.613984993806255e-16

# %% [markdown]
# ### 6. Mengubah Tipe Data Atribut Angka
#
# ###### Sebelum mengubah tipe data, baca file csv untuk melihat tipe data sebelum diubah dengan fungsi .dtypes

# %%
angka = pd.read_csv("Breast_Cancer.csv")

# %%
angka["Tumor Size"].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# ###### Mengubah atribut bertipe data angka menjadi object menggunakan fungsi .astype(object)

# %%
tipe_baru = angka[["Tumor Size"]].astype("object")
tipe_baru["Tumor Size"].dtypes
# Out:
# dtype('O')

# %% [markdown]
# ###### Tipe data telah berubah

# %%
tipe_baru.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tumor Size  4024 non-null   object
# dtypes: object(1)
# memory usage: 31.6+ KB

# %% [markdown]
# ## ENCODING
# ### 7. One Hot Encoding

# %%
data_encoding = pd.read_csv("Breast_Cancer.csv")

# %% [markdown]
# ###### Menerapkan One-Hot Encoding menggunakan kelas OneHotEncoder dari Scikit-Learn
#
# Disini saya menggunakan atribut 'Marital Status'

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
onehotencoder = OneHotEncoder(sparse=False)

# %%
Marital_Status_encoder = onehotencoder.fit_transform(data_encoding[['Marital Status']])

# %%
Marital_Status = pd.DataFrame(Marital_Status_encoder)
data_encoding = data_encoding.join(Marital_Status)

# %%
data_encoding.head(10)
# Out:
#    Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0   68  White        Married       T1      N1       IIA
# 1   50  White        Married       T2      N2      IIIA
# 2   58  White       Divorced       T3      N3      IIIC
# 3   58  White        Married       T1      N1       IIA
# 4   47  White        Married       T2      N1       IIB
# 5   51  White        Single        T1      N1       IIA
# 6   51  White        Married       T1      N1       IIA
# 7   40  White        Married       T2      N1       IIB
# 8   40  White       Divorced       T4      N3      IIIC
# 9   69  White        Married       T4      N3      IIIC
#
#                differentiate Grade   A Stage  Tumor Size  ...  \
# 0      Poorly differentiated     3  Regional           4  ...
# 1  Moderately differentiated     2  Regional          35  ...
# 2  Moderately differentiated     2  Regional          63  ...
# 3      Poorly differentiated     3  Regional          18  ...
# ...

# %% [markdown]
# ###### Menerapkan One-Hot Encoding menggunakan get_dummies dari Pandas
#
# Disini saya menggunakan atribut 'Status'

# %%
Status_encoder = pd.get_dummies(data_encoding[['Status']])

# %%
Status = pd.DataFrame(Status_encoder)
data_encoding = data_encoding.join(Status)

# %%
data_encoding.head(10)
# Out:
#    Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0   68  White        Married       T1      N1       IIA
# 1   50  White        Married       T2      N2      IIIA
# 2   58  White       Divorced       T3      N3      IIIC
# 3   58  White        Married       T1      N1       IIA
# 4   47  White        Married       T2      N1       IIB
# 5   51  White        Single        T1      N1       IIA
# 6   51  White        Married       T1      N1       IIA
# 7   40  White        Married       T2      N1       IIB
# 8   40  White       Divorced       T4      N3      IIIC
# 9   69  White        Married       T4      N3      IIIC
#
#                differentiate Grade   A Stage  Tumor Size  ...  \
# 0      Poorly differentiated     3  Regional           4  ...
# 1  Moderately differentiated     2  Regional          35  ...
# 2  Moderately differentiated     2  Regional          63  ...
# 3      Poorly differentiated     3  Regional          18  ...
# ...
